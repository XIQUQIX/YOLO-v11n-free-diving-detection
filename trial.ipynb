# %% [markdown]
# # 检测潜水运动员位置
#
# 通过仿射变换得出运动员真实位移速度

# %%
from ultralytics import YOLO

# 加载预训练模型
model = YOLO("yolo11n.pt")

# %%
from ultralytics import YOLO

# 加载预训练模型
model = YOLO("yolov8n.pt")

# 训练，减少 workers
model.train(
    data="new_dataset/data.yaml",
    epochs=60,
    imgsz=416,
    batch=8,
    device=0,
    workers=2,  # 减少工作线程
    name="swimmer_train",
    project="runs/train",
    exist_ok=True,
)

# %% [markdown]
# ### 图片预测

# %%
from ultralytics import YOLO
import cv2

# 加载训练好的模型
model = YOLO("runs/train/swimmer_train/weights/best.pt")

# 测试多张图像
results = model.predict(
    source="new_dataset/test/images",  # 测试集目录
    device=0,
    iou=0.5,
    conf=0.25,
    save=True,
    save_dir="new_dataset/predict",
)

# 显示单张结果
for result in results:
    img = result.plot()  # 带边界框的图像
    cv2.imshow("Result", img)
    cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 视频预测

# %%
from ultralytics import YOLO

# 加载训练好的模型
model = YOLO("runs/train/swimmer_train/weights/best.pt")

# 视频文件路径
video_path = "free_dive_video/007_clipped.mp4"

# 进行视频预测
results = model.predict(
    source=video_path,
    device=0,  # 使用 GPU
    conf=0.25,  # 置信度阈值
    iou=0.5,  # IOU 阈值，减少框重叠
    save=True,  # 保存结果视频
    save_dir="runs/detect/predict",  # 保存路径
)

# # 可选：实时显示视频结果
# cap = cv2.VideoCapture(video_path)
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break
#     # 预测单帧
#     result = model(frame, device=0, conf=0.25, iou=0.5)
#     annotated_frame = result[0].plot()  # 绘制边界框
#     cv2.imshow("YOLOv8 Prediction", annotated_frame)
#     if cv2.waitKey(1) & 0xFF == ord("q"):
#         break
# cap.release()
# cv2.destroyAllWindows()
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.2ms
# video 1/1 (frame 2/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.9ms
# video 1/1 (frame 3/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 6.5ms
# video 1/1 (frame 4/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 6.0ms
# video 1/1 (frame 5/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.9ms
# video 1/1 (frame 6/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.7ms
# video 1/1 (frame 7/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 7.2ms
# video 1/1 (frame 8/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.9ms
# video 1/1 (frame 9/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.8ms
# video 1/1 (frame 10/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.7ms
# video 1/1 (frame 11/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.8ms
# video 1/1 (frame 12/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 6.1ms
# video 1/1 (frame 13/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.9ms
# video 1/1 (frame 14/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 6.7ms
# video 1/1 (frame 15/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 1 0, 4.7ms
# video 1/1 (frame 16/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.2ms
# video 1/1 (frame 17/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.1ms
# video 1/1 (frame 18/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.6ms
# video 1/1 (frame 19/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 7.8ms
# video 1/1 (frame 20/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.7ms
# video 1/1 (frame 21/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.1ms
# video 1/1 (frame 22/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.6ms
# video 1/1 (frame 23/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 1 0, 5.9ms
# video 1/1 (frame 24/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 12.3ms
# video 1/1 (frame 25/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 6.4ms
# video 1/1 (frame 26/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.3ms
# video 1/1 (frame 27/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.6ms
# video 1/1 (frame 28/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 4.7ms
# video 1/1 (frame 29/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.7ms
# video 1/1 (frame 30/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5.8ms
# video 1/1 (frame 31/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 8.3ms
# video 1/1 (frame 32/3660) e:\\\SMT\free_swim\free_dive_video\007_clipped.mp4: 416x416 (no detections), 5
ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\predict5

# %% [markdown]
# ### pt 转 onnx

# %%
from ultralytics import YOLO

# 加载训练好的模型
model = YOLO("epoch_200.pt")


# Export the model to ONNX format
model.export(format="onnx")  # creates 'yolo11n.onnx'
# Out:
# Ultralytics 8.3.169  Python-3.10.11 torch-2.0.0+cu118 CPU (12th Gen Intel Core(TM) i7-12700H)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'epoch_200.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: slimming with onnxslim 0.1.61...
# ONNX: export success  3.2s, saved as 'epoch_200.onnx' (10.0 MB)
#
# Export complete (3.6s)
# Results saved to E:\\\SMT\free_swim
# Predict:         yolo predict task=detect model=epoch_200.onnx imgsz=640
# Validate:        yolo val task=detect model=epoch_200.onnx imgsz=640 data=other_dataset/data.yaml
# Visualize:       https://netron.app
# 'epoch_200.onnx'

# %%
import onnxruntime
import numpy as np
import cv2
import os
from pathlib import Path


def preprocess_image(image_path, input_size=(416, 416)):
    """预处理图像：读取、调整大小、归一化"""
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"无法读取图像: {image_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # 调整大小，保持比例
    img_resized, ratio, (dw, dh) = letterbox(img, new_shape=input_size)
    # 调试：检查调整后的图像尺寸
    print(f"预处理后图像尺寸: {img_resized.shape}")
    # 归一化
    img_resized = img_resized.astype(np.float32) / 255.0
    # 转换为 NCHW 格式 (1, C, H, W)
    img_resized = img_resized.transpose(2, 0, 1)
    img_resized = np.expand_dims(img_resized, axis=0)
    # 调试：检查最终输入尺寸
    print(f"模型输入尺寸: {img_resized.shape}")
    return img_resized, ratio, (dw, dh)


def letterbox(
    img,
    new_shape=(416, 416),
    color=(114, 114, 114),
    auto=False,
    scaleFill=False,
    scaleup=True,
):
    """调整图像大小并填充，保持比例，确保输出为 new_shape"""
    shape = img.shape[:2]  # 当前形状 [height, width]
    if isinstance(new_shape, int):
        new_shape = (new_shape, new_shape)

    # 计算缩放比例
    r = min(new_shape[0] / shape[0], new_shape[1] / shape[1])
    if not scaleup:  # 不放大
        r = min(r, 1.0)

    # 计算调整后的尺寸
    new_unpad = int(round(shape[1] * r)), int(round(shape[0] * r))
    dw, dh = new_shape[1] - new_unpad[0], new_shape[0] - new_unpad[1]  # wh padding

    # 确保填充后尺寸精确匹配 new_shape
    if auto:  # 最小矩形（避免填充过多）
        dw, dh = np.mod(dw, 32), np.mod(dh, 32)

    dw /= 2  # 分割填充
    dh /= 2

    if shape[::-1] != new_unpad:  # 调整大小
        img = cv2.resize(img, new_unpad, interpolation=cv2.INTER_LINEAR)

    top, bottom = int(round(dh - 0.1)), int(round(dh + 0.1))
    left, right = int(round(dw - 0.1)), int(round(dw + 0.1))
    img = cv2.copyMakeBorder(
        img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color
    )  # 添加边框

    # 验证最终尺寸
    if img.shape[:2] != new_shape:
        img = cv2.resize(img, new_shape, interpolation=cv2.INTER_LINEAR)

    return img, (r, r), (dw, dh)


def non_max_suppression(
    prediction, conf_thres=0.01, iou_thres=0.45, max_det=300, single_class=True
):
    """执行非极大值抑制 (NMS)，适配单类别模型，使用 cv2.dnn.NMSBoxes"""
    # prediction: [batch, num_boxes, 5] (x, y, w, h, conf)
    max_wh = 4096  # 最大框宽高限制

    output = [None] * prediction.shape[0]
    for xi, x in enumerate(prediction):  # 逐批次处理
        print(f"处理批次 {xi}, 初始框数量: {x.shape[0]}")
        # 过滤低置信度框
        scores = x[:, 4]  # 置信度
        xc = scores > conf_thres
        x = x[xc]
        scores = scores[xc]
        if not x.shape[0]:
            print(f"警告: 图像 {xi} 无检测框（置信度 > {conf_thres}）")
            continue

        print(f"置信度过滤后框数量: {x.shape[0]}")
        print(f"前5个框置信度: {scores[:5]}")  # 调试置信度

        # 提取坐标
        boxes = x[:, :4]  # x, y, w, h

        # 对于单类别模型，类别固定为 0
        if single_class:
            classes = np.zeros(x.shape[0], dtype=np.int32)  # 单类别，cls=0
        else:
            if x.shape[1] <= 5:
                print(f"错误: 模型输出缺少类别信息，形状为 {x.shape}")
                continue
            classes = np.argmax(x[:, 5:], axis=1)

        # 转换为 (x1, y1, x2, y2) 格式以便计算 IoU
        boxes_xyxy = np.zeros_like(boxes)
        boxes_xyxy[:, 0] = boxes[:, 0] - boxes[:, 2] / 2  # x1 = x - w/2
        boxes_xyxy[:, 1] = boxes[:, 1] - boxes[:, 3] / 2  # y1 = y - h/2
        boxes_xyxy[:, 2] = boxes[:, 0] + boxes[:, 2] / 2  # x2 = x + w/2
        boxes_xyxy[:, 3] = boxes[:, 1] + boxes[:, 3] / 2  # y2 = y + h/2

        # 过滤无效框
        valid = (
            (boxes_xyxy[:, 2] > boxes_xyxy[:, 0])
            & (boxes_xyxy[:, 3] > boxes_xyxy[:, 1])
            & (boxes_xyxy[:, 2] - boxes_xyxy[:, 0] < max_wh)
            & (boxes_xyxy[:, 3] - boxes_xyxy[:, 1] < max_wh)
        )
        boxes_xyxy = boxes_xyxy[valid]
        scores = scores[valid]
        classes = classes[valid]

        if not boxes_xyxy.shape[0]:
            print(f"警告: 图像 {xi} 无有效框")
            continue

        print(f"有效框过滤后数量: {boxes_xyxy.shape[0]}")
        print(f"前5个框坐标: {boxes_xyxy[:5]}")  # 调试框坐标

        # 使用 cv2.dnn.NMSBoxes 进行 NMS
        boxes_list = boxes_xyxy.astype(np.float32).tolist()  # 转换为 list
        scores_list = scores.tolist()
        indices = cv2.dnn.NMSBoxes(boxes_list, scores_list, conf_thres, iou_thres)

        if len(indices) == 0:
            print(f"警告: 图像 {xi} NMS 后无框")
            continue

        # 限制最大检测框数量
        if len(indices) > max_det:
            indices = indices[:max_det]

        print(f"NMS 后框数量: {len(indices)}")

        # 格式化输出: [x1, y1, x2, y2, conf, cls]
        det = np.concatenate(
            [boxes_xyxy[indices], scores[indices][:, None], classes[indices][:, None]],
            axis=1,
        )
        output[xi] = det

    return output


def postprocess(outputs, conf_thres=0.01, iou_thres=0.45, is_yolov8=True):
    """后处理：NMS 非极大值抑制"""
    print(f"原始输出形状: {outputs.shape}")
    if is_yolov8:
        outputs = np.transpose(outputs, (0, 2, 1))  # 转换为 [batch, num_boxes, 5]
    print(f"后处理后形状: {outputs.shape}")
    detections = non_max_suppression(
        outputs, conf_thres=conf_thres, iou_thres=iou_thres, single_class=True
    )
    return detections


def draw_boxes(image, detections, class_names, ratio, dwdh):
    """在图像上绘制检测框"""
    img = image.copy()
    for det in detections:
        if det is None or len(det) == 0:
            print("无检测框可绘制")
            continue
        print(f"绘制框数量: {len(det)}")
        for *xyxy, conf, cls in det:
            # 调整坐标到原始图像尺寸
            x1, y1, x2, y2 = xyxy
            x1 = int((x1 - dwdh[0]) / ratio[0])
            y1 = int((y1 - dwdh[1]) / ratio[1])
            x2 = int((x2 - dwdh[0]) / ratio[0])
            y2 = int((y2 - dwdh[1]) / ratio[1])
            # 绘制框
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"{class_names[int(cls)]}: {conf:.2f}"
            cv2.putText(
                img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2
            )
    return img


def main():
    # 配置参数
    onnx_model_path = "runs/train/swimmer_train/weights/best.onnx"  # ONNX 模型路径
    test_dir = "new_dataset/test/images"  # 测试集目录
    input_size = (416, 416)  # 模型输入尺寸
    class_names = ["swimmer"]  # 类别名称
    conf_thres = 0.01  # 置信度阈值（降低以保留更多框）
    iou_thres = 0.45  # NMS IoU 阈值
    output_dir = "output"  # 保存结果的目录
    is_yolov8 = True  # YOLOv8 格式

    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)

    # 加载 ONNX 模型
    session = onnxruntime.InferenceSession(
        onnx_model_path, providers=["CUDAExecutionProvider", "CPUExecutionProvider"]
    )

    # 打印模型输入信息
    print("模型输入信息:")
    for input in session.get_inputs():
        print(f"Input name: {input.name}, Shape: {input.shape}, Type: {input.type}")

    # 获取测试集图像
    image_paths = list(Path(test_dir).glob("*.jpg")) + list(
        Path(test_dir).glob("*.png")
    )

    for image_path in image_paths:
        print(f"处理图像: {image_path}")
        # 预处理图像
        img_input, ratio, dwdh = preprocess_image(str(image_path), input_size)

        # 运行推理
        inputs = {session.get_inputs()[0].name: img_input}
        outputs = session.run(None, inputs)[0]
        print(f"模型输出形状: {outputs.shape}")

        # 后处理
        detections = postprocess(outputs, conf_thres, iou_thres, is_yolov8=is_yolov8)

        # 读取原始图像以绘制结果
        img = cv2.imread(str(image_path))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # 绘制检测框
        img_result = draw_boxes(img, detections, class_names, ratio, dwdh)

        # 保存结果
        output_path = os.path.join(output_dir, f"result_{image_path.name}")
        img_result = cv2.cvtColor(img_result, cv2.COLOR_RGB2BGR)
        cv2.imwrite(output_path, img_result)
        print(f"结果已保存至: {output_path}")


if __name__ == "__main__":
    main()
# Out:
# 模型输入信息:
# Input name: images, Shape: [1, 3, 416, 416], Type: tensor(float)
# 处理图像: new_dataset\test\images\004_jpg.rf.9e4f53342583d3fe266f01ac72d252c2.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 88
# 前5个框置信度: [0.02231184 0.09183019 0.17360815 0.06721133 0.01284987]
# 有效框过滤后数量: 88
# 前5个框坐标: [[313.7717  154.03264 349.4476  159.68196]
#  [325.55164 154.3086  349.2279  159.78552]
#  [328.14764 154.2583  349.388   159.78693]
#  [327.48035 154.31747 349.63702 159.53506]
#  [356.2622  187.35866 391.39795 198.04848]]
# NMS 后框数量: 9
# 绘制框数量: 9
# 结果已保存至: output\result_004_jpg.rf.9e4f53342583d3fe266f01ac72d252c2.jpg
# 处理图像: new_dataset\test\images\016_jpg.rf.d766dd4b0bc8dc293f50903198a61155.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 96
# 前5个框置信度: [0.01186833 0.09125158 0.1599336  0.16424131 0.02233437]
# 有效框过滤后数量: 96
# 前5个框坐标: [[168.05528  112.030235 201.6504   117.49441 ]
#  [181.04579  109.98064  213.85493  117.17804 ]
#  [182.53583  109.445816 214.06287  117.063614]
#  [182.16257  109.26178  213.38028  117.160126]
#  [182.07698  110.23153  215.00621  117.58753 ]]
# NMS 后框数量: 6
# 绘制框数量: 6
# 结果已保存至: output\result_016_jpg.rf.d766dd4b0bc8dc293f50903198a61155.jpg
# 处理图像: new_dataset\test\images\033_jpg.rf.832c7391f7d257df4a4c6e100edf37c2.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 83
# 前5个框置信度: [0.13855103 0.5488075  0.5058715  0.39044282 0.12499297]
# 有效框过滤后数量: 83
# 前5个框坐标: [[271.69196  105.84781  373.98187  119.10501 ]
#  [268.80457  105.504974 373.9945   119.02576 ]
#  [267.14508  105.67381  373.75446  119.229996]
#  [270.6515   104.408264 377.05347  118.8465  ]
#  [274.96683  103.27341  375.85422  118.187744]]
# NMS 后框数量: 5
# 绘制框数量: 5
# 结果已保存至: output\result_033_jpg.rf.832c7391f7d257df4a4c6e100edf37c2.jpg
# 处理图像: new_dataset\test\images\036_jpg.rf.050ff8d805f7184bdc433bfd8737b380.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 133
# 前5个框置信度: [0.01443535 0.08399644 0.12142596 0.07752532 0.07300302]
# 有效框过滤后数量: 133
# 前5个框坐标: [[-3.1025887e-02  8.7912094e+01  8.1616898e+00  1.0495885e+02]
#  [ 3.0978607e+02  8.5283554e+01  3.6492743e+02  9.5689072e+01]
#  [ 3.1655084e+02  8.5452545e+01  3.6563531e+02  9.5456757e+01]
#  [ 3.1700610e+02  8.5623428e+01  3.6462769e+02  9.5370972e+01]
#  [ 3.1895697e+02  8.6508392e+01  3.6434564e+02  9.5396790e+01]]
# NMS 后框数量: 9
# 绘制框数量: 9
# 结果已保存至: output\result_036_jpg.rf.050ff8d805f7184bdc433bfd8737b380.jpg
# 处理图像: new_dataset\test\images\039_jpg.rf.8037907445b51a0951add9d5716ce36e.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 96
# 前5个框置信度: [0.05764368 0.30462652 0.22477743 0.14817452 0.07577303]
# 有效框过滤后数量: 96
# 前5个框坐标: [[329.04843   94.29694  383.85025  107.56747 ]
#  [330.58063   94.826355 383.83856  108.41803 ]
#  [330.82825   95.35179  385.5312   108.98717 ]
#  [331.31482   96.19356  382.9204   108.65199 ]
#  [333.03485   96.80517  384.3294   109.01177 ]]
# NMS 后框数量: 5
# 绘制框数量: 5
# 结果已保存至: output\result_039_jpg.rf.8037907445b51a0951add9d5716ce36e.jpg
# 处理图像: new_dataset\test\images\a_210_jpg.rf.ec728e2b837b9319c57029ae2197b07e.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.02953878 0.41506892 0.7989852  0.86913997 0.24520582]
# 有效框过滤后数量: 11
# 前5个框坐标: [[243.60474 159.1625  281.22534 227.8598 ]
#  [243.89871 159.28516 281.65958 228.0296 ]
#  [243.25153 158.8547  281.79785 227.7663 ]
#  [243.45938 159.0623  281.90207 227.95906]
#  [243.1008  157.97623 281.45853 228.04892]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_a_210_jpg.rf.ec728e2b837b9319c57029ae2197b07e.jpg
# 处理图像: new_dataset\test\images\frame_003_jpg.rf.77e6b37dedaf6bb4484110f96a862429.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 21
# 前5个框置信度: [0.46952966 0.7827805  0.7582801  0.74205077 0.7505213 ]
# 有效框过滤后数量: 21
# 前5个框坐标: [[167.54034 161.42192 194.86768 208.09111]
#  [167.92848 161.61798 194.91606 208.16946]
#  [167.60486 161.92596 194.91077 208.56134]
#  [167.99167 161.69235 194.32126 207.43634]
#  [168.31766 162.17264 194.31522 207.57022]]
# NMS 后框数量: 2
# 绘制框数量: 2
# 结果已保存至: output\result_frame_003_jpg.rf.77e6b37dedaf6bb4484110f96a862429.jpg
# 处理图像: new_dataset\test\images\frame_007_jpg.rf.5a962fdf074ba8d82f6f18e8c046ecc5.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 22
# 前5个框置信度: [0.16302133 0.43647426 0.6884357  0.6921096  0.6912098 ]
# 有效框过滤后数量: 22
# 前5个框坐标: [[176.43213 163.53276 196.1402  199.4756 ]
#  [176.13815 163.66574 196.28189 199.60495]
#  [176.0122  163.68173 196.16864 198.51431]
#  [175.53773 163.57315 195.95241 198.7908 ]
#  [175.34497 163.78549 196.1947  198.24918]]
# NMS 后框数量: 2
# 绘制框数量: 2
# 结果已保存至: output\result_frame_007_jpg.rf.5a962fdf074ba8d82f6f18e8c046ecc5.jpg
# 处理图像: new_dataset\test\images\frame_090_jpg.rf.a45a5ecdec3347735eb2f2c222bcda9d.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 13
# 前5个框置信度: [0.03763458 0.7094997  0.79559827 0.8210637  0.75071305]
# 有效框过滤后数量: 13
# 前5个框坐标: [[189.31506 203.03743 215.41821 242.89717]
#  [189.19856 203.0987  215.98494 243.52524]
#  [189.20169 203.03473 215.69598 243.20084]
#  [189.09608 203.16321 215.69719 243.57355]
#  [188.83243 202.78369 215.14737 243.46313]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_frame_090_jpg.rf.a45a5ecdec3347735eb2f2c222bcda9d.jpg
# 处理图像: new_dataset\test\images\frame_094_jpg.rf.68244c74552e7b4e648bd3d031054b33.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 12
# 前5个框置信度: [0.7261952  0.78357315 0.59928817 0.7910259  0.7569058 ]
# 有效框过滤后数量: 12
# 前5个框坐标: [[189.80765 200.0929  217.30777 237.69061]
#  [190.71971 199.81474 217.47945 238.28194]
#  [190.71094 200.08615 217.20862 238.26776]
#  [189.9328  199.78848 217.06604 237.35446]
#  [190.8623  200.05457 217.13702 237.66742]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_frame_094_jpg.rf.68244c74552e7b4e648bd3d031054b33.jpg
# 处理图像: new_dataset\test\images\frame_095_jpg.rf.3f363c6e1b96c9bf55b562bdcd34a6db.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 12
# 前5个框置信度: [0.04019472 0.01108158 0.8086505  0.7868345  0.05452582]
# 有效框过滤后数量: 12
# 前5个框坐标: [[186.27856 186.94522 213.94107 228.82718]
#  [186.2922  188.34845 213.22983 228.07846]
#  [186.42293 187.4504  213.80144 228.34541]
#  [186.64954 187.1247  214.18677 228.78354]
#  [186.51517 188.3894  213.36258 228.00787]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_frame_095_jpg.rf.3f363c6e1b96c9bf55b562bdcd34a6db.jpg
# 处理图像: new_dataset\test\images\frame_097_jpg.rf.ba906f12d6fe650fc7ee69b050a7f00f.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 13
# 前5个框置信度: [0.02257007 0.7629129  0.526578   0.11375657 0.7819422 ]
# 有效框过滤后数量: 13
# 前5个框坐标: [[249.13275 143.73808 262.2312  154.15538]
#  [186.90762 171.93976 212.90048 208.40973]
#  [187.29556 171.94902 213.07416 208.40553]
#  [186.36914 172.18066 212.78186 207.60825]
#  [186.72025 172.01622 212.82608 207.76097]]
# NMS 后框数量: 2
# 绘制框数量: 2
# 结果已保存至: output\result_frame_097_jpg.rf.ba906f12d6fe650fc7ee69b050a7f00f.jpg
# 处理图像: new_dataset\test\images\frame_136_jpg.rf.7899698abee5cebbee3061807a5cf5a2.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.81357   0.7543497 0.8841514 0.7467235 0.3574776]
# 有效框过滤后数量: 11
# 前5个框坐标: [[238.56131 157.98853 282.63956 220.66287]
#  [237.97748 158.05292 282.43365 220.43402]
#  [237.99701 158.6053  282.64734 220.82896]
#  [238.81987 158.39578 282.88348 220.90866]
#  [238.0444  158.92061 283.03897 220.24693]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_frame_136_jpg.rf.7899698abee5cebbee3061807a5cf5a2.jpg
# 处理图像: new_dataset\test\images\f_037_jpg.rf.fded3ee9e07d871d6febdea342d1ebda.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 23
# 前5个框置信度: [0.05404726 0.8254312  0.81309456 0.07050136 0.730135  ]
# 有效框过滤后数量: 23
# 前5个框坐标: [[121.48636  183.14009  198.3487   202.23964 ]
#  [122.12931  182.80557  200.24655  202.7576  ]
#  [122.026924 182.26321  200.32697  202.7663  ]
#  [121.379814 182.41962  200.1164   202.59189 ]
#  [121.91098  183.0986   198.43582  202.13052 ]]
# NMS 后框数量: 2
# 绘制框数量: 2
# 结果已保存至: output\result_f_037_jpg.rf.fded3ee9e07d871d6febdea342d1ebda.jpg
# 处理图像: new_dataset\test\images\m_003_jpg.rf.5ec984fc134a8cbdb0553717e3bf1236.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 12
# 前5个框置信度: [0.5296452  0.7377159  0.7873575  0.01543897 0.6714516 ]
# 有效框过滤后数量: 12
# 前5个框坐标: [[ 62.805664 194.12036  379.44296  265.95532 ]
#  [ 58.968445 192.64621  384.6233   266.6813  ]
#  [ 59.80081  184.50967  381.34183  268.1425  ]
#  [ 63.5791   178.41473  384.344    267.16455 ]
#  [ 62.891907 192.0823   382.19388  264.2702  ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_003_jpg.rf.5ec984fc134a8cbdb0553717e3bf1236.jpg
# 处理图像: new_dataset\test\images\m_006_jpg.rf.4c69a09e8f17aeafb95ca7ea4b0745b3.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.52589506 0.7981608  0.8062243  0.80688494 0.68554384]
# 有效框过滤后数量: 10
# 前5个框坐标: [[158.87518 202.8162  404.21942 257.9742 ]
#  [162.27531 202.87723 404.61115 258.1279 ]
#  [162.8642  203.39792 402.30542 258.63693]
#  [159.07036 203.52426 402.72125 259.28378]
#  [159.01122 202.93423 404.21265 259.72388]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_006_jpg.rf.4c69a09e8f17aeafb95ca7ea4b0745b3.jpg
# 处理图像: new_dataset\test\images\m_008_jpg.rf.36adbf48952ef4840cf3a6be8a25149a.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.49595234 0.835412   0.8433982  0.8187423  0.8292426 ]
# 有效框过滤后数量: 10
# 前5个框坐标: [[147.80756 205.90045 382.3922  269.27582]
#  [149.01819 205.87253 393.5426  272.67047]
#  [148.27536 205.11237 407.76352 273.87662]
#  [148.16217 206.36441 381.211   270.37305]
#  [147.97366 206.50964 397.32675 272.26498]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_008_jpg.rf.36adbf48952ef4840cf3a6be8a25149a.jpg
# 处理图像: new_dataset\test\images\m_009_jpg.rf.7c41936d766c7ca722e6616ef7ed82fe.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.86108565 0.87536895 0.8389796  0.04106197 0.8839371 ]
# 有效框过滤后数量: 11
# 前5个框坐标: [[178.00452 206.11652 392.85754 262.8655 ]
#  [178.74124 206.11865 393.8353  263.73877]
#  [180.39069 205.4722  397.45544 265.09695]
#  [179.09564 206.65335 393.29816 260.99445]
#  [178.1471  206.59387 391.8518  262.16046]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_009_jpg.rf.7c41936d766c7ca722e6616ef7ed82fe.jpg
# 处理图像: new_dataset\test\images\m_022_jpg.rf.9934d33f18f9c5e87b768835eb205fbd.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.01916629 0.8970306  0.78756875 0.881245   0.89352185]
# 有效框过滤后数量: 11
# 前5个框坐标: [[144.3002  163.63185 320.12845 243.50697]
#  [143.78003 164.1163  319.9782  244.2113 ]
#  [143.3837  163.50885 320.23654 243.81122]
#  [144.49475 163.27646 319.87866 242.99686]
#  [143.55832 163.0925  320.45975 243.09787]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_022_jpg.rf.9934d33f18f9c5e87b768835eb205fbd.jpg
# 处理图像: new_dataset\test\images\m_024_jpg.rf.e3f58d823ba77b87eca03197fd294df9.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.8522178  0.88346636 0.8785441  0.06265146 0.83877504]
# 有效框过滤后数量: 11
# 前5个框坐标: [[168.05101 171.19695 357.95984 233.20406]
#  [167.33264 170.94437 359.46613 233.33252]
#  [167.4375  170.67572 358.06195 234.08588]
#  [167.95967 173.17722 355.1911  233.03934]
#  [168.44629 171.81992 356.92883 233.21707]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_024_jpg.rf.e3f58d823ba77b87eca03197fd294df9.jpg
# 处理图像: new_dataset\test\images\m_038_jpg.rf.8b1acdaaba736b82537b2e6408a225e5.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.19762164 0.85712004 0.05359864 0.8615557  0.8586497 ]
# 有效框过滤后数量: 10
# 前5个框坐标: [[182.20132 176.95712 377.64255 241.5918 ]
#  [181.09344 177.98141 378.5078  242.11536]
#  [181.70839 175.85583 378.3927  239.86261]
#  [182.17139 177.65146 379.38    241.00531]
#  [180.44052 178.46194 379.01804 241.379  ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_038_jpg.rf.8b1acdaaba736b82537b2e6408a225e5.jpg
# 处理图像: new_dataset\test\images\m_046_jpg.rf.1177b734844aebfa1c45332baeee73ef.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.88838893 0.870072   0.8731653  0.01238769 0.9005989 ]
# 有效框过滤后数量: 11
# 前5个框坐标: [[112.49042 152.77603 239.85446 233.81284]
#  [112.82623 152.74484 238.65533 233.50772]
#  [113.48605 152.8858  238.47076 233.38574]
#  [113.84217 152.94632 238.13599 234.22733]
#  [112.6172  152.9077  239.51213 233.20418]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_046_jpg.rf.1177b734844aebfa1c45332baeee73ef.jpg
# 处理图像: new_dataset\test\images\m_051_jpg.rf.be8424e9b523d0ded1c69bfeb75d166d.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.881329   0.89469266 0.8151283  0.8609538  0.876758  ]
# 有效框过滤后数量: 10
# 前5个框坐标: [[ 71.39554  138.23131  251.80508  246.17455 ]
#  [ 71.389336 138.37625  252.34106  246.0018  ]
#  [ 72.10967  138.07265  252.55139  245.81416 ]
#  [ 70.75065  138.16113  251.79037  244.52576 ]
#  [ 71.15677  138.39517  251.8913   244.83115 ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_051_jpg.rf.be8424e9b523d0ded1c69bfeb75d166d.jpg
# 处理图像: new_dataset\test\images\m_053_jpg.rf.10f5307ff2a27f62e80581deb33ee1e9.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.87671316 0.8690883  0.8271189  0.8436487  0.8833624 ]
# 有效框过滤后数量: 10
# 前5个框坐标: [[ 77.473366 173.3316   300.86063  262.53595 ]
#  [ 79.32211  173.27951  299.87085  261.97864 ]
#  [ 79.10098  172.71457  300.40326  260.73776 ]
#  [ 76.8186   172.3508   298.6585   262.94434 ]
#  [ 76.62672  172.61002  301.69684  262.4586  ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_053_jpg.rf.10f5307ff2a27f62e80581deb33ee1e9.jpg
# 处理图像: new_dataset\test\images\m_055_jpg.rf.5b8d3c4a36993f8cd3654ba0d5624a9c.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.8794135  0.89798033 0.91431475 0.82336485 0.90215683]
# 有效框过滤后数量: 10
# 前5个框坐标: [[ 83.79995  157.17221  275.61362  264.25284 ]
#  [ 82.24546  157.26782  276.31955  263.88214 ]
#  [ 83.53995  157.35364  276.31647  263.112   ]
#  [ 84.093864 158.70224  277.39478  264.61206 ]
#  [ 83.56686  159.26633  276.9305   263.63303 ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_055_jpg.rf.5b8d3c4a36993f8cd3654ba0d5624a9c.jpg
# 处理图像: new_dataset\test\images\m_057_jpg.rf.f64d382385f72d9d7cfbadbe9b61a6ff.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 12
# 前5个框置信度: [0.34155732 0.6738297  0.87887454 0.8911788  0.90601945]
# 有效框过滤后数量: 12
# 前5个框坐标: [[ 71.99619  163.50127  273.0317   249.79051 ]
#  [ 72.00506  163.30997  273.53186  250.72232 ]
#  [ 71.59079  163.1987   275.11234  250.18375 ]
#  [ 71.695595 163.25262  273.62332  250.08313 ]
#  [ 71.6528   163.52795  273.06558  250.06848 ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_057_jpg.rf.f64d382385f72d9d7cfbadbe9b61a6ff.jpg
# 处理图像: new_dataset\test\images\m_092_jpg.rf.cbc9fed7f104ffca00ad1556744b5f9c.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.9115515  0.92930245 0.93319684 0.7296153  0.9137949 ]
# 有效框过滤后数量: 11
# 前5个框坐标: [[139.8581  168.84085 310.29242 258.80396]
#  [140.34595 169.23282 312.2071  259.99893]
#  [138.90115 169.52072 311.57693 259.7139 ]
#  [138.1648  169.68408 311.66626 258.80377]
#  [140.01822 169.43713 310.91458 258.50854]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_092_jpg.rf.cbc9fed7f104ffca00ad1556744b5f9c.jpg
# 处理图像: new_dataset\test\images\m_096_jpg.rf.2480a480ed18a3ae3bdc909758cd8ff8.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 11
# 前5个框置信度: [0.8961139 0.919952  0.8861655 0.8736732 0.8957453]
# 有效框过滤后数量: 11
# 前5个框坐标: [[176.74469 165.42703 353.01282 236.36902]
#  [175.40726 165.52145 352.80734 237.15189]
#  [174.43619 165.48077 353.1757  237.51282]
#  [177.05916 163.59837 350.56647 235.52843]
#  [177.7334  165.12607 353.52448 235.94443]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_096_jpg.rf.2480a480ed18a3ae3bdc909758cd8ff8.jpg
# 处理图像: new_dataset\test\images\m_105_jpg.rf.b0f82c17ed5f85aad7dccd5b058ecd44.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 10
# 前5个框置信度: [0.04615989 0.910758   0.911612   0.89865565 0.91772294]
# 有效框过滤后数量: 10
# 前5个框坐标: [[196.35204 170.82977 349.46106 249.68665]
#  [195.57385 170.63379 348.98083 249.81195]
#  [196.19658 170.90741 348.95245 250.01923]
#  [195.24861 171.62338 350.18207 250.5747 ]
#  [196.46973 170.38928 348.7868  249.88525]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_105_jpg.rf.b0f82c17ed5f85aad7dccd5b058ecd44.jpg
# 处理图像: new_dataset\test\images\m_143_jpg.rf.fcd3408b2dce210174438b4862efebf6.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 13
# 前5个框置信度: [0.16338745 0.08412242 0.7718848  0.7720181  0.8075402 ]
# 有效框过滤后数量: 13
# 前5个框坐标: [[ 39.075867 178.35486  290.84076  243.10995 ]
#  [ 38.762154 178.64935  290.3603   241.27048 ]
#  [ 39.552765 187.56848  291.8189   246.89676 ]
#  [ 39.226173 187.21768  290.61404  246.76749 ]
#  [ 38.77636  187.35239  289.48566  248.84079 ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_143_jpg.rf.fcd3408b2dce210174438b4862efebf6.jpg
# 处理图像: new_dataset\test\images\m_166_jpg.rf.8cf0d35cc92057fc2a142d6e458f9c5c.jpg
# 预处理后图像尺寸: (416, 416, 3)
# 模型输入尺寸: (1, 3, 416, 416)
# 模型输出形状: (1, 5, 3549)
# 原始输出形状: (1, 5, 3549)
# 后处理后形状: (1, 3549, 5)
# 处理批次 0, 初始框数量: 3549
# 置信度过滤后框数量: 12
# 前5个框置信度: [0.6529885  0.46759233 0.8535787  0.8460384  0.83115697]
# 有效框过滤后数量: 12
# 前5个框坐标: [[ 52.401833 151.22415  304.65024  247.08255 ]
#  [ 53.928375 151.50742  303.25217  248.77011 ]
#  [ 51.186615 150.28671  305.2429   248.87003 ]
#  [ 51.766792 149.74619  306.25323  248.44037 ]
#  [ 53.281197 149.57709  303.7093   248.5924  ]]
# NMS 后框数量: 1
# 绘制框数量: 1
# 结果已保存至: output\result_m_166_jpg.rf.8cf0d35cc92057fc2a142d6e458f9c5c.jpg
